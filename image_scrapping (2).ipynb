# %%
# Importing the necessary classes
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as url
import logging
import os

# %%
# Checking the existence of the directory then creating it
save_dir = "images/"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
# Working with the main url for the time being
query = "tom"
url = f"https://www.google.com/search?rlz=1C1CHBF_enIN997IN997&sxsrf=AB5stBhuM3QSO1JYG2uLfk5sveVCq2Afig:1688745427043&q={query}&tbm=isch&sa=X&sqi=2&ved=2ahUKEwjk1K36-vz_AhU6XWwGHQAfDe8Q0pQJegQIEhAB&biw=1536&bih=746&dpr=1.25"

# %%
# Sample header to avoid errors during frequent scraping
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}

# %%
# Sends a GET request to accept the string as an hyperlink 
response = requests.get(f"https://www.google.com/search?rlz=1C1CHBF_enIN997IN997&sxsrf=AB5stBiQXw_7J_C3xzpwIeiC5ZMbbJf6Zg:1688790059407&q={query}&tbm=isch&sa=X&ved=2ahUKEwiYh92cof7_AhVCxTgGHfVjAGQQ0pQJegQIDRAB&biw=1536&bih=714&dpr=1.25")

# %%
# Returns 200 if the link is accepted else returns 404
response
# Out:
# <Response [200]>

# %%
 # Beautifies the contents of the hyperlink through Beautiful Soap 
# Html parser is a  structured markup processing tool to parse Html files
soup = bs(response.content , 'html.parser')
soup
# Out:
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# ...

# %%
# Searching the image tags from a list of HTML contents
images = soup.find_all("img")

# %%
# Finding the length
len(images)
# Out:
# 21

# %%
# As the first image is of the hamburger menu so delete it
del images[0]

# %%
images
# Out:
# [<img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT5nGZjPUEurLRn9Uc0bv3uEmLXBMsfZwxN6ZSjYepXCiPmpdI4CDySPJJkPA&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSUBL1uc_dBgGOV9l8S6Q3nY0hs_Q01ONS16Td6oBCxjN9aScz_VLTNLKPjzrs&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQHZiGpbi3h3MZZ1a0JIutUwzQV9YUvG4nARDhk9tiKMhNRKBpLHhAVHFy1rA&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTfnQqxo9WwaoS5xkRMGYzPtzO47CktuX1npgGtleyTdBSphi9Wr3nb_FdZWg&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTYVdVA-z7GqDgTb3Q37T_MyTTQxR03lU1pzLp_BFjMfS9FS1yebqFQOJyUoA&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQlWyv7ae4sqTntqWNdwM2u-C6AR1wpc3fUBu7r0xp4CPN9eEP-cGscEv5-SQ&amp;s"/>,
# ...

# %%
# Creaing and storing the contents in a dictionary
image_info = []
for i in images:
    image_url = i['src']
    image_data = requests.get(image_url).content
    mydict = {"index":image_url , "images":image_data}
    image_info.append(mydict)
    print (image_info)
# Out:
# [{'index': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT5nGZjPUEurLRn9Uc0bv3uEmLXBMsfZwxN6ZSjYepXCiPmpdI4CDySPJJkPA&s', 'images': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x08\x07\x06\t\x08\x07\x08\n\n\t\x0b\r\x16\x0f\r\x0c\x0c\r\x1b\x14\x15\x10\x16 \x1d"" \x1d\x1f\x1f$(4,$&1\'\x1f\x1f-=-157:::#+?D?8C49:7\x01\n\n\n\r\x0c\r\x1a\x0f\x0f\x1a7%\x1f%77777777777777777777777777777777777777777777777777\xff\xc0\x00\x11\x08\x00\x8c\x00\x8c\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x01\x05\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x06\x01\x03\x04\x05\x07\x00\x02\x08\xff\xc4\x00@\x10\x00\x01\x03\x03\x03\x02\x02\x06\x06\x08\x04\x07\x00\x00\x00\x00\x01\x02\x03\x04\x00\x05\x11\x06\x12!1A\x13Q"2aq\x81\x91\x07\x14BR\xa1\xb1\x15#$r\xa2\xc1\xd1\xf0b\x82\xc2\xd2\x16%4c\x92\xa4\xb2\xff\xc4\x00\x1b\x01\x00\x01\x05\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x02\x03\x04\x05\x06\x07\xff\xc4\x00
# ...

# %%
# Importing the MongoDB class for storing the images
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo
from pymongo import MongoClient

# %%
# Connecting to the MongoDB CLient 
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://saptarshideyed123:saptarshi123@cluster0.7r2ufjj.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# Storing the images in the form of JPG to the MongoDB Server
image_info = []
for i in images:
    image_url = i['src']
    image_data = requests.get(image_url).content
    mydict = {"index":image_url , "images":image_data}
    image_info.append(mydict)
    with open(os.path.join(save_dir,f"{query}_{images.index(i)}.jpg"),"wb") as f :
        f.write(image_data)    
client = MongoClient(uri)
db = client["image_scrap"]
coll_image = db["image_scrap"]
coll_image.insert_many(image_info)
